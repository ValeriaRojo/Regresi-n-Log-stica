# %% [markdown]
# **Regresión Logística México**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import seaborn as sns
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Cargar archivos csv desde seaborn
df = pd.read_csv("MEXICO_procesado_outliers (1).csv")
df.head(5)
# Out:
#    Unnamed: 0 last_scraped host_name  host_since        host_location  \
# 0           0   2024-12-27      Dici  2010-06-28  Mexico City, Mexico
# 1           1   2024-12-28  Fernando  2010-08-09  Mexico City, Mexico
# 2           2   2024-12-28  Nicholas  2011-01-04  Mexico City, Mexico
# 3           3   2024-12-27    Trisha  2010-08-24  Mexico City, Mexico
# 4           4   2024-12-28  Fernando  2011-05-31  Mexico City, Mexico
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0             Unknown                 0%                   0%
# 1      within an hour                92%                  92%
# 2  within a few hours               100%                  56%
# 3      within an hour               100%                  94%
# 4             Unknown                 0%                   0%
#
#   host_is_superhost host_has_profile_pic  ... number_of_reviews_l30d  \
# 0                 f                    t  ...                    0.0
# 1                 t                    t  ...                    0.0
# 2                 t                    t  ...                    0.0
# 3                 t                    t  ...                    2.0
# 4                 f                    t  ...                    0.0
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                 4.80                   4.90                      4.80
# 1                 4.58                   4.56                      4.70
# 2                 4.90                   4.82                      4.76
# 3                 4.91                   4.91                      4.96
# 4                 4.80                   4.90                      4.80
#
#   review_scores_checkin review_scores_location  \
# 0                  4.90                   4.90
# 1                  4.87                   4.98
# 2                  4.94                   4.98
# 3                  4.96                   4.96
# 4                  4.90                   4.90
#
#   calculated_host_listings_count_entire_homes  \
# 0                                         1.0
# 1                                         4.0
# 2                                         2.0
# 3                                         2.0
# 4                                         1.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          1.0
# 2                                          0.0
# 3                                          1.0
# 4                                          2.0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                         0.0              1.20
# 1                                         0.0              0.40
# 2                                         0.0              0.31
# 3                                         0.0              0.84
# 4                                         0.0              1.20
#
# [5 rows x 51 columns]

# %%
df=df.fillna(method='bfill')
df=df.fillna(method='ffill')
# Out:
# C:\Users\ghseb\AppData\Local\Temp\ipykernel_18228\1110552620.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df=df.fillna(method='bfill')
# C:\Users\ghseb\AppData\Local\Temp\ipykernel_18228\1110552620.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df=df.fillna(method='ffill')

# %%
#Declaramos las variables dependientes e independientes para la regresion logistica
Var_Indep= df[['pclass', 'age', 'fare']]
Var_Dep= df['alive']

# %%
#Dividimos el conjunto de datos en la parte de entrenamiento y prueba:
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=None)
